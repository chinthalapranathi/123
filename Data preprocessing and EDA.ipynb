# %% [markdown]
# # DATA PROCESSING

# %%
# With pandas, one can efficiently analyze, manipulate, and process data 
import pandas as pd

# %%
# pd.read_csv() function in pandas is used to read data from a CSV file and create a DataFrame object.

data_eo = pd.read_csv(r'C:\Users\rithi\OneDrive\Desktop\major project-team 8\datasets\data\Economic Offences.csv')
data_w = pd.read_csv(r'C:\Users\rithi\OneDrive\Desktop\major project-team 8\datasets\data\Crime Against Women .csv')
data_cc = pd.read_csv(r'C:\Users\rithi\OneDrive\Desktop\major project-team 8\datasets\data\Cyber Crime.csv')
data_v = pd.read_csv(r'C:\Users\rithi\OneDrive\Desktop\major project-team 8\datasets\data\Violent Crimes.csv')
data_ka = pd.read_csv(r'C:\Users\rithi\OneDrive\Desktop\major project-team 8\datasets\data\Kidnapping and Abduction.csv')
data_sll = pd.read_csv(r'C:\Users\rithi\OneDrive\Desktop\major project-team 8\datasets\data\SLL.csv')
data_ipc = pd.read_csv(r'C:\Users\rithi\OneDrive\Desktop\major project-team 8\datasets\data\IPC.csv')

# %% [markdown]
# #### Merging multiple datasets into a single dataset

# %%
# pd.merge() function is used to combine data from multiple DataFrames based on a common key or keys.
# 'common_key' - 'Year' and 'City'

data = pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(data_eo, data_w, on=['City', 'Year'], how='inner'), data_cc, on=['City', 'Year'], how='inner'), data_v, on=['City', 'Year'], how='inner'), data_ka, on=['City', 'Year'], how='inner'), data_sll, on=['City', 'Year'], how='inner'), data_ipc, on=['City', 'Year'], how='inner')

# %%
# to_csv() function in pandas is used to save a DataFrame object as a CSV file

data.to_csv('dataset_data.csv', index=False)

# %%
#  to print the contents of a DataFrame named 'data'

print(data)
# Out:
#     Year        City  eo cases  w cases  cc cases  violent cases  \
# 0   2017   Ahmedabad       608     1681       108             90
# 1   2017   Bengaluru      3463     5624       292            235
# 2   2017     Chennai       663     1980        31            154
# 3   2017  Coimbatore       145      101        33             21
# 4   2017       Delhi      4808    32081       187            400
# ..   ...         ...       ...      ...       ...            ...
# 90  2021      Mumbai      5671    17180      1584             95
# 91  2021      Nagpur       541     1627       261             76
# 92  2021       Patna      1181     1071       517            100
# 93  2021        Pune       705     2709       411            121
# 94  2021       Surat       663      682       421           1955
#
#     Below 6 Years- M  Below 6 Years- F  Below 6 Years- T  6 to 12 yrs- M  ...  \
# 0                  4                 1                 5              11  ...
# ...

# %%
# info() method in pandas provides a summary of the DataFrame's structure

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 58 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              95 non-null     int64
#  1   City              95 non-null     object
#  2   eo cases          95 non-null     int64
#  3   w cases           95 non-null     int64
#  4   cc cases          95 non-null     int64
#  5   violent cases     95 non-null     int64
#  6   Below 6 Years- M  95 non-null     int64
#  7   Below 6 Years- F  95 non-null     int64
#  8   Below 6 Years- T  95 non-null     int64
#  9   6 to 12 yrs- M    95 non-null     int64
#  10  6 to 12 yrs- F    95 non-null     int64
#  11  6 to 12 yrs- T    95 non-null     int64
#  12  12  to 16 yrs- M  95 non-null     int64
#  13  12  to 16 yrs- F  95 non-null     int64
#  14  12  to 16 yrs- T  95 non-null     int64
#  15  16  to 18 yrs- M  95 non-null     int64
# ...

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# ### handling missing values

# %%
# Identify missing values

missing_values = data.isnull().sum()

# %%
print(missing_values)
# Out:
# Year                 0
# City                 0
# eo cases             0
# w cases              0
# cc cases             0
# violent cases        0
# Below 6 Years- M     0
# Below 6 Years- F     0
# Below 6 Years- T     0
# 6 to 12 yrs- M       0
# 6 to 12 yrs- F       0
# 6 to 12 yrs- T       0
# 12  to 16 yrs- M     0
# 12  to 16 yrs- F     0
# 12  to 16 yrs- T     0
# 16  to 18 yrs- M     0
# 16  to 18 yrs- F     0
# 16  to 18 yrs- T     0
# 18 to 30 yrs- M      0
# 18 to 30 yrs- F      0
# 18 to 30 yrs- T      0
# 30 to 60 yrs- M      0
# 30 to 60 yrs- F      0
# 30 to 60 yrs- T      0
# Above 60 yrs- M      0
# Above 60 yrs- F      0
# Above 60 yrs- T      0
# Unnamed: 23_x       95
# Unnamed: 24_x       95
# Unnamed: 25_x       95
# Unnamed: 26         95
# Unnamed: 27         95
# Unnamed: 28         95
# sll cases            0
# Unnamed: 3          95
# Unnamed: 4          95
# Unnamed: 5          95
# Unnamed: 6          95
# Unnamed: 7          95
# Unnamed: 8          95
# ...

# %%
# used to check for missing or null values in a DataFrame

data.isnull()
# Out:
#      Year   City  eo cases  w cases  cc cases  violent cases  \
# 0   False  False     False    False     False          False
# 1   False  False     False    False     False          False
# 2   False  False     False    False     False          False
# 3   False  False     False    False     False          False
# 4   False  False     False    False     False          False
# ..    ...    ...       ...      ...       ...            ...
# 90  False  False     False    False     False          False
# 91  False  False     False    False     False          False
# 92  False  False     False    False     False          False
# 93  False  False     False    False     False          False
# 94  False  False     False    False     False          False
#
#     Below 6 Years- M  Below 6 Years- F  Below 6 Years- T  6 to 12 yrs- M  ...  \
# 0              False             False             False           False  ...
# ...

# %%
#  drop columns (axis=1) from the DataFrame data where all values in the column are missing (NaN)
'''

data.dropna(): This method is used to remove missing values from the DataFrame.
axis=1: It specifies that we want to drop columns. Setting axis=0 would drop rows.
how='all': It indicates that a column will only be dropped if all values in that column are missing (NaN). If any value is present, the column will not be dropped.'''


data=data.dropna(axis=1,how='all')

# %%
data.isnull()
# Out:
#      Year   City  eo cases  w cases  cc cases  violent cases  \
# 0   False  False     False    False     False          False
# 1   False  False     False    False     False          False
# 2   False  False     False    False     False          False
# 3   False  False     False    False     False          False
# 4   False  False     False    False     False          False
# ..    ...    ...       ...      ...       ...            ...
# 90  False  False     False    False     False          False
# 91  False  False     False    False     False          False
# 92  False  False     False    False     False          False
# 93  False  False     False    False     False          False
# 94  False  False     False    False     False          False
#
#     Below 6 Years- M  Below 6 Years- F  Below 6 Years- T  6 to 12 yrs- M  ...  \
# 0              False             False             False           False  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              95 non-null     int64
#  1   City              95 non-null     object
#  2   eo cases          95 non-null     int64
#  3   w cases           95 non-null     int64
#  4   cc cases          95 non-null     int64
#  5   violent cases     95 non-null     int64
#  6   Below 6 Years- M  95 non-null     int64
#  7   Below 6 Years- F  95 non-null     int64
#  8   Below 6 Years- T  95 non-null     int64
#  9   6 to 12 yrs- M    95 non-null     int64
#  10  6 to 12 yrs- F    95 non-null     int64
#  11  6 to 12 yrs- T    95 non-null     int64
#  12  12  to 16 yrs- M  95 non-null     int64
#  13  12  to 16 yrs- F  95 non-null     int64
#  14  12  to 16 yrs- T  95 non-null     int64
#  15  16  to 18 yrs- M  95 non-null     int64
# ...

# %%
# Dataset is Clean?

print("Number of Missing Values in the whole dataset : ", data.isna().sum().sum())
# Out:
# Number of Missing Values in the whole dataset :  0

# %% [markdown]
# #### missing values removed

# %% [markdown]
# ### handling outliers

# %%
import numpy as np

# Select multiple desired attributes
attributes = ['eo cases', 'w cases', 'cc cases', 'violent cases', 'sll cases', 'ipc cases']  

# Calculate the Z-score for each data point in the selected columns
z_scores = data[attributes].apply(lambda x: (x - x.mean()) / x.std())

# Set a threshold for outlier detection (e.g., Z-score > 3 or Z-score < -3)
threshold = 3

# Identify outliers
outliers = data[np.abs(z_scores) > threshold]

# Display the outliers
print(outliers)
# Out:
#     Year City  eo cases  w cases  cc cases  violent cases  Below 6 Years- M  \
# 0    NaN  NaN       NaN      NaN       NaN            NaN               NaN
# 1    NaN  NaN       NaN      NaN       NaN            NaN               NaN
# 2    NaN  NaN       NaN      NaN       NaN            NaN               NaN
# 3    NaN  NaN       NaN      NaN       NaN            NaN               NaN
# 4    NaN  NaN       NaN      NaN       NaN            NaN               NaN
# ..   ...  ...       ...      ...       ...            ...               ...
# 90   NaN  NaN       NaN      NaN       NaN            NaN               NaN
# 91   NaN  NaN       NaN      NaN       NaN            NaN               NaN
# 92   NaN  NaN       NaN      NaN       NaN            NaN               NaN
# 93   NaN  NaN       NaN      NaN       NaN            NaN               NaN
# 94   NaN  NaN       NaN      NaN       NaN         1955.0               NaN
#
# ...

# %%
print(data.head())
# Out:
#    Year        City  eo cases  w cases  cc cases  violent cases  \
# 0  2017   Ahmedabad       608     1681       108             90
# 1  2017   Bengaluru      3463     5624       292            235
# 2  2017     Chennai       663     1980        31            154
# 3  2017  Coimbatore       145      101        33             21
# 4  2017       Delhi      4808    32081       187            400
#
#    Below 6 Years- M  Below 6 Years- F  Below 6 Years- T  6 to 12 yrs- M  ...  \
# 0                 4                 1                 5              11  ...
# 1                17                11                28              41  ...
# 2                 3                 4                 7               2  ...
# 3                 0                 0                 0               0  ...
# 4               109                72               181             467  ...
#
#    18 to 30 yrs- F  18 to 30 yrs- T  30 to 60 yrs- M  30 to 60 yrs- F  \
# ...

# %% [markdown]
# #### no outliers found

# %% [markdown]
# ### handling duplicates or redundant data

# %%
# Identify duplicate records
duplicates = data.duplicated()

# %%
# Remove duplicate records
data_unique = data[~duplicates]

# %%
# Display the updated dataset
print(data_unique.head())
# Out:
#    Year        City  eo cases  w cases  cc cases  violent cases  \
# 0  2017   Ahmedabad       608     1681       108             90
# 1  2017   Bengaluru      3463     5624       292            235
# 2  2017     Chennai       663     1980        31            154
# 3  2017  Coimbatore       145      101        33             21
# 4  2017       Delhi      4808    32081       187            400
#
#    Below 6 Years- M  Below 6 Years- F  Below 6 Years- T  6 to 12 yrs- M  ...  \
# 0                 4                 1                 5              11  ...
# 1                17                11                28              41  ...
# 2                 3                 4                 7               2  ...
# 3                 0                 0                 0               0  ...
# 4               109                72               181             467  ...
#
#    18 to 30 yrs- F  18 to 30 yrs- T  30 to 60 yrs- M  30 to 60 yrs- F  \
# ...

# %%
print(duplicates)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 90    False
# 91    False
# 92    False
# 93    False
# 94    False
# Length: 95, dtype: bool

# %% [markdown]
# #### no redundant data found

# %% [markdown]
# ## DATA TRANSFORMATION

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
numerical_features = ['eo cases', 'w cases', 'cc cases', 'violent cases', 'sll cases', 'ipc cases']

# %%
# Standardization
scaler = StandardScaler()
data_standardized = pd.DataFrame(scaler.fit_transform(data[numerical_features]), columns=numerical_features)

# %%
# Display the scaled datasets
print("Standardized Data:")
print(data_standardized.head())
# Out:
# Standardized Data:
#    eo cases   w cases  cc cases  violent cases  sll cases  ipc cases
# 0 -0.639715 -0.449454 -0.329451      -0.184431   0.651968  -0.683011
# 1  1.106862 -0.011615 -0.275240       0.341778   0.389631  -0.071969
# 2 -0.606068 -0.416252 -0.352137       0.047827  -0.418191  -0.498536
# 3 -0.922961 -0.624900 -0.351548      -0.434834  -0.728986  -0.890183
# 4  1.929681  2.926226 -0.306175       0.940567   1.865772   3.642636

# %%
# Normalization
min_max_scaler = MinMaxScaler(feature_range=(0, 1))
data_normalized = pd.DataFrame(min_max_scaler.fit_transform(data[numerical_features]), columns=numerical_features)

# %%
print("\nNormalized Data:")
print(data_normalized.head())
# Out:
# Normalized Data:
#    eo cases   w cases  cc cases  violent cases  sll cases  ipc cases
# 0  0.085786  0.025671  0.003832       0.043590   0.294866   0.043954
# 1  0.560432  0.089736  0.010882       0.117949   0.241922   0.173594
# 2  0.094929  0.030530  0.000881       0.076410   0.078890   0.083093
# 3  0.008811  0.000000  0.000958       0.008205   0.016167   0.000000
# 4  0.784040  0.519603  0.006859       0.202564   0.539832   0.961692

# %% [markdown]
# ## DATA INSPECTION AND EXPLORATION - EDA

# %% [markdown]
# # Exploratory Data Dnalysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              95 non-null     int64
#  1   City              95 non-null     object
#  2   eo cases          95 non-null     int64
#  3   w cases           95 non-null     int64
#  4   cc cases          95 non-null     int64
#  5   violent cases     95 non-null     int64
#  6   Below 6 Years- M  95 non-null     int64
#  7   Below 6 Years- F  95 non-null     int64
#  8   Below 6 Years- T  95 non-null     int64
#  9   6 to 12 yrs- M    95 non-null     int64
#  10  6 to 12 yrs- F    95 non-null     int64
#  11  6 to 12 yrs- T    95 non-null     int64
#  12  12  to 16 yrs- M  95 non-null     int64
#  13  12  to 16 yrs- F  95 non-null     int64
#  14  12  to 16 yrs- T  95 non-null     int64
#  15  16  to 18 yrs- M  95 non-null     int64
# ...

# %%
# To retrieve the shape of a DataFrame

data_shape = data.shape  
print(data_shape)
# Out:
# (95, 29)

# %%
#displays the first 15 rows of the DataFrame

data.head(15)
# Out:
#     Year        City  eo cases  w cases  cc cases  violent cases  \
# 0   2017   Ahmedabad       608     1681       108             90
# 1   2017   Bengaluru      3463     5624       292            235
# 2   2017     Chennai       663     1980        31            154
# 3   2017  Coimbatore       145      101        33             21
# 4   2017       Delhi      4808    32081       187            400
# 5   2017   Ghaziabad       473     1462        86             52
# 6   2017   Hyderabad      2037     3690       166             64
# 7   2017      Indore       264     1627       149             64
# 8   2017      Jaipur      4318     2273       187             90
# 9   2017      Kanpur       765     1917       144             51
# 10  2017       Kochi       377      628       114             11
# 11  2017     Kolkata      2198     3104       133             64
# 12  2017   Kozhikode       167      586         8              7
# ...

# %%
# displays the last 15 rows of the DataFrame

data.tail(15)
# Out:
#     Year       City  eo cases  w cases  cc cases  violent cases  \
# 80  2021      Delhi      5102    29353       458             25
# 81  2021  Ghaziabad       595      594       259             98
# 82  2021  Hyderabad      4860     4699      1156             54
# 83  2021     Indore       395     2226       246            118
# 84  2021     Jaipur      4275     3741       402             48
# 85  2021     Kanpur       433     1559       875             10
# 86  2021      Kochi       434      724       215             45
# 87  2021    Kolkata      2077     4032       302              5
# 88  2021  Kozhikode       311      978        41            101
# 89  2021    Lucknow      3440     3147      1926            162
# 90  2021     Mumbai      5671    17180      1584             95
# 91  2021     Nagpur       541     1627       261             76
# 92  2021      Patna      1181     1071       517            100
# 93  2021       Pune       705     2709       411            121
# ...

# %%
# returns the column labels of the DataFrame

print(data.columns)
# Out:
# Index(['Year', 'City', 'eo cases', 'w cases', 'cc cases', 'violent cases',
#        'Below 6 Years- M', 'Below 6 Years- F', 'Below 6 Years- T',
#        '6 to 12 yrs- M', '6 to 12 yrs- F', '6 to 12 yrs- T',
#        '12  to 16 yrs- M', '12  to 16 yrs- F', '12  to 16 yrs- T',
#        '16  to 18 yrs- M', '16  to 18 yrs- F', '16  to 18 yrs- T',
#        '18 to 30 yrs- M', '18 to 30 yrs- F', '18 to 30 yrs- T',
#        '30 to 60 yrs- M', '30 to 60 yrs- F', '30 to 60 yrs- T',
#        'Above 60 yrs- M', 'Above 60 yrs- F', 'Above 60 yrs- T', 'sll cases',
#        'ipc cases'],
#       dtype='object')

# %%
# returns the data types of each column in the DataFrame

print(data.dtypes)
# Out:
# Year                 int64
# City                object
# eo cases             int64
# w cases              int64
# cc cases             int64
# violent cases        int64
# Below 6 Years- M     int64
# Below 6 Years- F     int64
# Below 6 Years- T     int64
# 6 to 12 yrs- M       int64
# 6 to 12 yrs- F       int64
# 6 to 12 yrs- T       int64
# 12  to 16 yrs- M     int64
# 12  to 16 yrs- F     int64
# 12  to 16 yrs- T     int64
# 16  to 18 yrs- M     int64
# 16  to 18 yrs- F     int64
# 16  to 18 yrs- T     int64
# 18 to 30 yrs- M      int64
# 18 to 30 yrs- F      int64
# 18 to 30 yrs- T      int64
# 30 to 60 yrs- M      int64
# 30 to 60 yrs- F      int64
# 30 to 60 yrs- T      int64
# Above 60 yrs- M      int64
# Above 60 yrs- F      int64
# Above 60 yrs- T      int64
# sll cases            int64
# ipc cases            int64
# dtype: object

# %%
#  provides descriptive statistics of the numeric columns in the DataFrame

print(data.describe())
# Out:
#               Year     eo cases       w cases      cc cases  violent cases  \
# count    95.000000    95.000000     95.000000     95.000000      95.000000
# mean   2019.000000  1653.694737   5728.600000   1226.200000     140.821053
# std       1.421716  1643.297037   9053.369628   3412.138107     277.017780
# min    2017.000000    92.000000    101.000000      8.000000       5.000000
# 25%    2018.000000   457.500000   1559.500000    126.500000      52.000000
# 50%    2019.000000   804.000000   2432.000000    320.000000      81.000000
# 75%    2020.000000  2722.000000   4765.000000    704.000000     119.500000
# max    2021.000000  6107.000000  61648.000000  26107.000000    1955.000000
#
#        Below 6 Years- M  Below 6 Years- F  Below 6 Years- T  6 to 12 yrs- M  \
# count         95.000000         95.000000         95.000000       95.000000
# mean           7.600000          6.284211         13.884211       39.115789
# ...

# %% [markdown]
# ## DATA MANIPULATION AND TRASNFORMATION

# %%
# Add a new column 'Above 100 yrs' indicating True or False


data['Above 100 yrs'] = data['Above 60 yrs- T'] > 61

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              95 non-null     int64
#  1   City              95 non-null     object
#  2   eo cases          95 non-null     int64
#  3   w cases           95 non-null     int64
#  4   cc cases          95 non-null     int64
#  5   violent cases     95 non-null     int64
#  6   Below 6 Years- M  95 non-null     int64
#  7   Below 6 Years- F  95 non-null     int64
#  8   Below 6 Years- T  95 non-null     int64
#  9   6 to 12 yrs- M    95 non-null     int64
#  10  6 to 12 yrs- F    95 non-null     int64
#  11  6 to 12 yrs- T    95 non-null     int64
#  12  12  to 16 yrs- M  95 non-null     int64
#  13  12  to 16 yrs- F  95 non-null     int64
#  14  12  to 16 yrs- T  95 non-null     int64
#  15  16  to 18 yrs- M  95 non-null     int64
# ...

# %%
# Drop the 'Above 100 yrs' column
data = data.drop('Above 100 yrs', axis=1)

# Verify the updated DataFrame
print(data)
# Out:
#     Year        City  eo cases  w cases  cc cases  violent cases  \
# 0   2017   Ahmedabad       608     1681       108             90
# 1   2017   Bengaluru      3463     5624       292            235
# 2   2017     Chennai       663     1980        31            154
# 3   2017  Coimbatore       145      101        33             21
# 4   2017       Delhi      4808    32081       187            400
# ..   ...         ...       ...      ...       ...            ...
# 90  2021      Mumbai      5671    17180      1584             95
# 91  2021      Nagpur       541     1627       261             76
# 92  2021       Patna      1181     1071       517            100
# 93  2021        Pune       705     2709       411            121
# 94  2021       Surat       663      682       421           1955
#
#     Below 6 Years- M  Below 6 Years- F  Below 6 Years- T  6 to 12 yrs- M  ...  \
# 0                  4                 1                 5              11  ...
# ...

# %%
# Rename columns or index labels.

data.rename(columns = {'Year':'YEAR'}, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   YEAR              95 non-null     int64
#  1   City              95 non-null     object
#  2   eo cases          95 non-null     int64
#  3   w cases           95 non-null     int64
#  4   cc cases          95 non-null     int64
#  5   violent cases     95 non-null     int64
#  6   Below 6 Years- M  95 non-null     int64
#  7   Below 6 Years- F  95 non-null     int64
#  8   Below 6 Years- T  95 non-null     int64
#  9   6 to 12 yrs- M    95 non-null     int64
#  10  6 to 12 yrs- F    95 non-null     int64
#  11  6 to 12 yrs- T    95 non-null     int64
#  12  12  to 16 yrs- M  95 non-null     int64
#  13  12  to 16 yrs- F  95 non-null     int64
#  14  12  to 16 yrs- T  95 non-null     int64
#  15  16  to 18 yrs- M  95 non-null     int64
# ...

# %%
# sorting data frame by YEAR

data.sort_values("YEAR", axis = 0, ascending = True,
                 inplace = True, na_position ='last')

# %%
print(data)
# Out:
#     YEAR       City  eo cases  w cases  cc cases  violent cases  \
# 0   2017  Ahmedabad       608     1681       108             90
# 18  2017      Surat       719      587       102             89
# 17  2017       Pune      1046     3356       141            110
# 16  2017      Patna       156     1452       119            183
# 15  2017     Nagpur       509     1796        80             85
# ..   ...        ...       ...      ...       ...            ...
# 77  2021  Bengaluru      2715     4183      5968            161
# 76  2021  Ahmedabad       765     1837       612            155
# 93  2021       Pune       705     2709       411            121
# 84  2021     Jaipur      4275     3741       402             48
# 94  2021      Surat       663      682       421           1955
#
#     Below 6 Years- M  Below 6 Years- F  Below 6 Years- T  6 to 12 yrs- M  ...  \
# 0                  4                 1                 5              11  ...
# ...

# %% [markdown]
# ## DATA ANALYSIS AND AGGREGATION

# %%
#Calculate the sum of values in each column

data.sum()
# Out:
# YEAR                                                           191805
# City                AhmedabadSuratPunePatnaNagpurMumbaiKozhikodeKo...
# eo cases                                                       157101
# w cases                                                        544217
# cc cases                                                       116489
# violent cases                                                   13378
# Below 6 Years- M                                                  722
# Below 6 Years- F                                                  597
# Below 6 Years- T                                                 1319
# 6 to 12 yrs- M                                                   3716
# 6 to 12 yrs- F                                                   2474
# 6 to 12 yrs- T                                                   6190
# 12  to 16 yrs- M                                                 8772
# ...

# %%
# Calculate the median of values in each column

#data.median()
# Select only numeric columns from the DataFrame
numeric_data = data.select_dtypes(include=['number'])

# Calculate the median of values in each column
column_medians = numeric_data.median()

print(column_medians)
# Out:
# YEAR                 2019.0
# eo cases              804.0
# w cases              2432.0
# cc cases              320.0
# violent cases          81.0
# Below 6 Years- M        2.0
# Below 6 Years- F        2.0
# Below 6 Years- T        4.0
# 6 to 12 yrs- M         11.0
# 6 to 12 yrs- F          9.0
# 6 to 12 yrs- T         23.0
# 12  to 16 yrs- M       39.0
# 12  to 16 yrs- F       69.0
# 12  to 16 yrs- T      121.0
# 16  to 18 yrs- M       21.0
# 16  to 18 yrs- F       63.0
# 16  to 18 yrs- T       83.0
# 18 to 30 yrs- M        12.0
# 18 to 30 yrs- F        10.0
# 18 to 30 yrs- T        26.0
# 30 to 60 yrs- M        11.0
# 30 to 60 yrs- F         3.0
# 30 to 60 yrs- T        20.0
# Above 60 yrs- M         0.0
# Above 60 yrs- F         0.0
# Above 60 yrs- T         0.0
# sll cases           37534.0
# ipc cases           39440.0
# dtype: float64

# %%
#Calculate the mean of values in each column.

numeric_data.mean()
# Out:
# YEAR                 2019.000000
# eo cases             1653.694737
# w cases              5728.600000
# cc cases             1226.200000
# violent cases         140.821053
# Below 6 Years- M        7.600000
# Below 6 Years- F        6.284211
# Below 6 Years- T       13.884211
# 6 to 12 yrs- M         39.115789
# 6 to 12 yrs- F         26.042105
# 6 to 12 yrs- T         65.157895
# 12  to 16 yrs- M       92.336842
# 12  to 16 yrs- F      178.115789
# 12  to 16 yrs- T      270.452632
# 16  to 18 yrs- M       55.494737
# 16  to 18 yrs- F      188.452632
# 16  to 18 yrs- T      243.947368
# 18 to 30 yrs- M        32.821053
# 18 to 30 yrs- F        66.505263
# 18 to 30 yrs- T        99.326316
# 30 to 60 yrs- M        22.863158
# 30 to 60 yrs- F        25.305263
# 30 to 60 yrs- T        48.168421
# Above 60 yrs- M         1.789474
# Above 60 yrs- F         0.557895
# Above 60 yrs- T         2.347368
# sll cases           67255.947368
# ipc cases           75061.726316
# dtype: float64

# %%
#  Get the maximum value in each column

numeric_data.max()
# Out:
# YEAR                  2021
# eo cases              6107
# w cases              61648
# cc cases             26107
# violent cases         1955
# Below 6 Years- M       109
# Below 6 Years- F        72
# Below 6 Years- T       181
# 6 to 12 yrs- M         467
# 6 to 12 yrs- F         293
# 6 to 12 yrs- T         760
# 12  to 16 yrs- M       986
# 12  to 16 yrs- F      1901
# 12  to 16 yrs- T      2781
# 16  to 18 yrs- M       548
# 16  to 18 yrs- F      1604
# 16  to 18 yrs- T      2036
# 18 to 30 yrs- M        291
# 18 to 30 yrs- F        547
# 18 to 30 yrs- T        756
# 30 to 60 yrs- M        181
# 30 to 60 yrs- F        300
# 30 to 60 yrs- T        349
# Above 60 yrs- M         59
# Above 60 yrs- F         14
# Above 60 yrs- T         73
# sll cases           393571
# ipc cases           379758
# dtype: int64

# %%
#  Get the minimum value in each column

numeric_data.min()
# Out:
# YEAR                2017
# eo cases              92
# w cases              101
# cc cases               8
# violent cases          5
# Below 6 Years- M       0
# Below 6 Years- F       0
# Below 6 Years- T       0
# 6 to 12 yrs- M         0
# 6 to 12 yrs- F         0
# 6 to 12 yrs- T         0
# 12  to 16 yrs- M       0
# 12  to 16 yrs- F       0
# 12  to 16 yrs- T       0
# 16  to 18 yrs- M       0
# 16  to 18 yrs- F       0
# 16  to 18 yrs- T       0
# 18 to 30 yrs- M        0
# 18 to 30 yrs- F        0
# 18 to 30 yrs- T        0
# 30 to 60 yrs- M        0
# 30 to 60 yrs- F        0
# 30 to 60 yrs- T        0
# Above 60 yrs- M        0
# Above 60 yrs- F        0
# Above 60 yrs- T        0
# sll cases           3574
# ipc cases           4117
# dtype: int64

# %%
# Count non-null values in each column

numeric_data.count()
# Out:
# YEAR                95
# eo cases            95
# w cases             95
# cc cases            95
# violent cases       95
# Below 6 Years- M    95
# Below 6 Years- F    95
# Below 6 Years- T    95
# 6 to 12 yrs- M      95
# 6 to 12 yrs- F      95
# 6 to 12 yrs- T      95
# 12  to 16 yrs- M    95
# 12  to 16 yrs- F    95
# 12  to 16 yrs- T    95
# 16  to 18 yrs- M    95
# 16  to 18 yrs- F    95
# 16  to 18 yrs- T    95
# 18 to 30 yrs- M     95
# 18 to 30 yrs- F     95
# 18 to 30 yrs- T     95
# 30 to 60 yrs- M     95
# 30 to 60 yrs- F     95
# 30 to 60 yrs- T     95
# Above 60 yrs- M     95
# Above 60 yrs- F     95
# Above 60 yrs- T     95
# sll cases           95
# ipc cases           95
# dtype: int64

# %%
# Find the unique values in a specific column
unique_values = numeric_data['YEAR'].unique()

# Print the unique values
print(unique_values)
# Out:
# [2017 2018 2019 2020 2021]

# %%
#used to count the occurrences of unique values in a DataFrame column

numeric_data.value_counts()
# Out:
# YEAR  eo cases  w cases  cc cases  violent cases  Below 6 Years- M  Below 6 Years- F  Below 6 Years- T  6 to 12 yrs- M  6 to 12 yrs- F  6 to 12 yrs- T  12  to 16 yrs- M  12  to 16 yrs- F  12  to 16 yrs- T  16  to 18 yrs- M  16  to 18 yrs- F  16  to 18 yrs- T  18 to 30 yrs- M  18 to 30 yrs- F  18 to 30 yrs- T  30 to 60 yrs- M  30 to 60 yrs- F  30 to 60 yrs- T  Above 60 yrs- M  Above 60 yrs- F  Above 60 yrs- T  sll cases  ipc cases
# 2017  145       101      33        21             0                 0                 0                 0               0               0               1                 0                 1                 0                 1                 1                 2                1                3                0                0                0                0                0                0                9879       4117         1
# ...

# %%
#  calculates the quartiles of the numerical columns in the DataFrame

quartiles = numeric_data.quantile([0.25, 0.5, 0.75])

# %%
# Calculate summary statistics
summary_stats = numeric_data.describe()

# %%
# Print the summary statistics
print("Summary Statistics:")
print(summary_stats)
# Out:
# Summary Statistics:
#               YEAR     eo cases       w cases      cc cases  violent cases  \
# count    95.000000    95.000000     95.000000     95.000000      95.000000
# mean   2019.000000  1653.694737   5728.600000   1226.200000     140.821053
# std       1.421716  1643.297037   9053.369628   3412.138107     277.017780
# min    2017.000000    92.000000    101.000000      8.000000       5.000000
# 25%    2018.000000   457.500000   1559.500000    126.500000      52.000000
# 50%    2019.000000   804.000000   2432.000000    320.000000      81.000000
# 75%    2020.000000  2722.000000   4765.000000    704.000000     119.500000
# max    2021.000000  6107.000000  61648.000000  26107.000000    1955.000000
#
#        Below 6 Years- M  Below 6 Years- F  Below 6 Years- T  6 to 12 yrs- M  \
# count         95.000000         95.000000         95.000000       95.000000
# mean           7.600000          6.284211         13.884211       39.115789
# ...

# %%
# Extract specific statistics
mean = numeric_data.mean()
median = numeric_data.median()
std = numeric_data.std()
minimum = numeric_data.min()
maximum = numeric_data.max()
quartiles = numeric_data.quantile([0.25, 0.5, 0.75])

# %%
# Print specific statistics
print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std)
print("Minimum:", minimum)
print("Maximum:", maximum)
print("Quartiles:")
print(quartiles)
# Out:
# Mean: YEAR                 2019.000000
# eo cases             1653.694737
# w cases              5728.600000
# cc cases             1226.200000
# violent cases         140.821053
# Below 6 Years- M        7.600000
# Below 6 Years- F        6.284211
# Below 6 Years- T       13.884211
# 6 to 12 yrs- M         39.115789
# 6 to 12 yrs- F         26.042105
# 6 to 12 yrs- T         65.157895
# 12  to 16 yrs- M       92.336842
# 12  to 16 yrs- F      178.115789
# 12  to 16 yrs- T      270.452632
# 16  to 18 yrs- M       55.494737
# 16  to 18 yrs- F      188.452632
# 16  to 18 yrs- T      243.947368
# 18 to 30 yrs- M        32.821053
# 18 to 30 yrs- F        66.505263
# 18 to 30 yrs- T        99.326316
# 30 to 60 yrs- M        22.863158
# 30 to 60 yrs- F        25.305263
# 30 to 60 yrs- T        48.168421
# Above 60 yrs- M         1.789474
# Above 60 yrs- F         0.557895
# Above 60 yrs- T         2.347368
# sll cases           67255.947368
# ipc cases           75061.726316
# ...

# %% [markdown]
# ## DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data.describe().style.background_gradient(cmap='rainbow')
# Out:
# <style type="text/css">
# #T_5a102_row0_col0, #T_5a102_row0_col4, #T_5a102_row0_col16, #T_5a102_row1_col3, #T_5a102_row5_col13 {
#   background-color: #6a22fe;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ### Cases per Cities

# %%
# pd.merge() function is used to combine data from multiple DataFrames based on a common key or keys.
# 'common_key' - 'Year' and 'City'

data = pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(data_eo, data_w, on=['City', 'Year'], how='inner'), data_cc, on=['City', 'Year'], how='inner'), data_v, on=['City', 'Year'], how='inner'), data_ka, on=['City', 'Year'], how='inner'), data_sll, on=['City', 'Year'], how='inner'), data_ipc, on=['City', 'Year'], how='inner')

# %%
# to_csv() function in pandas is used to save a DataFrame object as a CSV file

data.to_csv('dataset_data.csv', index=False)
print(data)
# Out:
#     Year        City  eo cases  w cases  cc cases  violent cases  \
# 0   2017   Ahmedabad       608     1681       108             90
# 1   2017   Bengaluru      3463     5624       292            235
# 2   2017     Chennai       663     1980        31            154
# 3   2017  Coimbatore       145      101        33             21
# 4   2017       Delhi      4808    32081       187            400
# ..   ...         ...       ...      ...       ...            ...
# 90  2021      Mumbai      5671    17180      1584             95
# 91  2021      Nagpur       541     1627       261             76
# 92  2021       Patna      1181     1071       517            100
# 93  2021        Pune       705     2709       411            121
# 94  2021       Surat       663      682       421           1955
#
#     Below 6 Years- M  Below 6 Years- F  Below 6 Years- T  6 to 12 yrs- M  ...  \
# 0                  4                 1                 5              11  ...
# ...

# %%
import matplotlib.pyplot as plt

# Sort the data by 'eo cases' in descending order
sorted_data = data.sort_values(by='eo cases', ascending=False)

# Plotting the bar chart
plt.figure(figsize=(12, 6))
plt.bar(sorted_data['City'], sorted_data['eo cases'])
plt.xlabel('City')
plt.ylabel('Number of EO cases')
plt.title('Distribution of Economic Offence cases by City')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
#  Bar chart for Crime Against Women cases by city
plt.figure(figsize=(12, 6))
plt.bar(data['City'], data['w cases'])
plt.xlabel('City')
plt.ylabel('Number of cases')
plt.title('Distribution of Crime Against Women cases by City')
plt.xticks(rotation=45)
plt.show()

# %%
#  Bar chart for Cyber Crime cases by city
plt.figure(figsize=(12, 6))
plt.bar(data['City'], data['cc cases'])
plt.xlabel('City')
plt.ylabel('Number of cases')
plt.title('Distribution of Cyber Crime cases by City')
plt.xticks(rotation=45)
plt.show()

# %%
#  Bar chart for Violent Crime cases by city
plt.figure(figsize=(12, 6))
plt.bar(data['City'], data['violent cases'])
plt.xlabel('City')
plt.ylabel('Number of cases')
plt.title('Distribution of Violent Crime cases by City')
plt.xticks(rotation=45)
plt.show()

# %%
#  Bar chart for SLL-Special and Local Laws cases by city
plt.figure(figsize=(12, 6))
plt.bar(data['City'], data['sll cases'])
plt.xlabel('City')
plt.ylabel('Number of cases')
plt.title('Distribution of SLL-Special and Local Laws cases by City')
plt.xticks(rotation=45)
plt.show()

# %%
#  Bar chart for IPC (Indian Penal Code) cases by city
plt.figure(figsize=(12, 6))
plt.bar(data['City'], data['ipc cases'])
plt.xlabel('City')
plt.ylabel('Number of cases')
plt.title('Distribution of IPC (Indian Penal Code) cases by City')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Cases per year

# %%
# pd.merge() function is used to combine data from multiple DataFrames based on a common key or keys.
# 'common_key' - 'Year' and 'City'

data = pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(data_eo, data_w, on=['City', 'Year'], how='inner'), data_cc, on=['City', 'Year'], how='inner'), data_v, on=['City', 'Year'], how='inner'), data_ka, on=['City', 'Year'], how='inner'), data_sll, on=['City', 'Year'], how='inner'), data_ipc, on=['City', 'Year'], how='inner')

# to_csv() function in pandas is used to save a DataFrame object as a CSV file

data.to_csv('dataset_data.csv', index=False)
print(data)
# Out:
#     Year        City  eo cases  w cases  cc cases  violent cases  \
# 0   2017   Ahmedabad       608     1681       108             90
# 1   2017   Bengaluru      3463     5624       292            235
# 2   2017     Chennai       663     1980        31            154
# 3   2017  Coimbatore       145      101        33             21
# 4   2017       Delhi      4808    32081       187            400
# ..   ...         ...       ...      ...       ...            ...
# 90  2021      Mumbai      5671    17180      1584             95
# 91  2021      Nagpur       541     1627       261             76
# 92  2021       Patna      1181     1071       517            100
# 93  2021        Pune       705     2709       411            121
# 94  2021       Surat       663      682       421           1955
#
#     Below 6 Years- M  Below 6 Years- F  Below 6 Years- T  6 to 12 yrs- M  ...  \
# 0                  4                 1                 5              11  ...
# ...

# %%
#  Bar chart for Economic Offense cases by Year
plt.figure(figsize=(12, 6))

c = '#7eb54e'
plt.bar(data['Year'], data['eo cases'], color = c)
plt.xlabel('Year')
plt.ylabel('Number of cases')
plt.title('Distribution of Economic Offense cases by Year')
plt.xticks(rotation=45)
plt.show()

# %%
#  Bar chart for Crime Against Women cases by Year
plt.figure(figsize=(12, 6))

c = '#7eb54e'
plt.bar(data['Year'], data['w cases'], color = c)
plt.xlabel('Year')
plt.ylabel('Number of cases')
plt.title('Distribution of Economic Offense cases by Year')
plt.xticks(rotation=45)
plt.show()

# %%
#  Bar chart for Cyber Crime cases by Year
plt.figure(figsize=(12, 6))

c = '#7eb54e'
plt.bar(data['Year'], data['cc cases'], color = c)
plt.xlabel('Year')
plt.ylabel('Number of cases')
plt.title('Distribution of Cyber Crime cases by Year')
plt.xticks(rotation=45)
plt.show()

# %%
#  Bar chart for Violent Crimes cases by Year
plt.figure(figsize=(12, 6))

c = '#7eb54e'
plt.bar(data['Year'], data['violent cases'], color = c)
plt.xlabel('Year')
plt.ylabel('Number of cases')
plt.title('Distribution of Violent Crimes cases by Year')
plt.xticks(rotation=45)
plt.show()

# %%
#  Bar chart for SLL cases by Year
plt.figure(figsize=(12, 6))

c = '#7eb54e'
plt.bar(data['Year'], data['sll cases'], color = c)
plt.xlabel('Year')
plt.ylabel('Number of cases')
plt.title('Distribution of SLL cases by Year')
plt.xticks(rotation=45)
plt.show()

# %%
#  Bar chart for ipc cases by Year
plt.figure(figsize=(12, 6))

c = '#7eb54e'
plt.bar(data['Year'], data['ipc cases'], color = c)
plt.xlabel('Year')
plt.ylabel('Number of cases')
plt.title('Distribution of IPC cases by Year')
plt.xticks(rotation=45)
plt.show()

# %%
# Line plot for cases over the years
plt.figure(figsize=(12, 6))
plt.plot(data['Year'], data['eo cases'], label='Economic Offense cases')
plt.plot(data['Year'], data['w cases'], label='Crime ag Women cases')
plt.plot(data['Year'], data['cc cases'], label='Cyber Crime cases')
plt.plot(data['Year'], data['violent cases'], label='Violent Crime cases')
plt.plot(data['Year'], data['sll cases'], label='SLL cases')
plt.plot(data['Year'], data['ipc cases'], label='IPC cases')

plt.xlabel('Year')
plt.ylabel('Number of cases')
plt.title('Trend of Cases over the Years')
plt.legend()
plt.show()

# %%
# Line plot for Economic Offense cases over the years
plt.figure(figsize=(12, 6))
plt.plot(data['Year'], data['eo cases'], label='Economic Offense cases')

plt.xlabel('Year')
plt.ylabel('Number of cases')
plt.title('Trend of Cases over the Years')
plt.legend()
plt.show()

# %%
# Line plot for Crime ag Women cases over the years
plt.figure(figsize=(12, 6))
plt.plot(data['Year'], data['w cases'], label='Crime ag Women cases')

plt.xlabel('Year')
plt.ylabel('Number of cases')
plt.title('Trend of Cases over the Years')
plt.legend()
plt.show()

# %%
# Line plot for Cyber Crime cases over the years
plt.figure(figsize=(12, 6))
plt.plot(data['Year'], data['cc cases'], label='Cyber Crime cases')

plt.xlabel('Year')
plt.ylabel('Number of cases')
plt.title('Trend of Cases over the Years')
plt.legend()
plt.show()

# %%
# Line plot for Violent Crime cases over the years
plt.figure(figsize=(12, 6))
plt.plot(data['Year'], data['violent cases'], label='Violent Crime cases')

plt.xlabel('Year')
plt.ylabel('Number of cases')
plt.title('Trend of Cases over the Years')
plt.legend()
plt.show()

# %%
# Line plot for SLL cases over the years
plt.figure(figsize=(12, 6))
plt.plot(data['Year'], data['sll cases'], label='SLL cases')

plt.xlabel('Year')
plt.ylabel('Number of cases')
plt.title('Trend of Cases over the Years')
plt.legend()
plt.show()

# %%
# Line plot for IPC cases over the years
plt.figure(figsize=(12, 6))
plt.plot(data['Year'], data['ipc cases'], label='IPC cases')

plt.xlabel('Year')
plt.ylabel('Number of cases')
plt.title('Trend of Cases over the Years')
plt.legend()
plt.show()

# %%
import warnings


# Stacked bar chart for age group cases


age_groups = ['Below 6 Years', '6 to 12 yrs', '12 to 16 yrs', '16 to 18 yrs', '18 to 30 yrs', '30 to 60 yrs', 'Above 60 yrs']
# Temporarily ignore the warning
warnings.filterwarnings("ignore", category=UserWarning)

male_cases = data[['Below 6 Years- M', '6 to 12 yrs- M', '12  to 16 yrs- M', '16  to 18 yrs- M', '18 to 30 yrs- M', '30 to 60 yrs- M', 'Above 60 yrs- M']].sum()
female_cases = data[['Below 6 Years- F', '6 to 12 yrs- F', '12  to 16 yrs- F', '16  to 18 yrs- F', '18 to 30 yrs- F', '30 to 60 yrs- F', 'Above 60 yrs- F']].sum()
total_cases = data[['Below 6 Years- T', '6 to 12 yrs- T', '12  to 16 yrs- T', '16  to 18 yrs- T', '18 to 30 yrs- T', '30 to 60 yrs- T', 'Above 60 yrs- T']].sum()

# Reset the warning filter
warnings.resetwarnings()

plt.figure(figsize=(12, 6))
plt.bar(age_groups, male_cases, label='Male')
plt.bar(age_groups, female_cases, bottom=male_cases, label='Female')
plt.bar(age_groups, total_cases, bottom=male_cases+female_cases, label='Total')
plt.xlabel('Age Groups')
plt.ylabel('Number of Cases')
plt.title('Distribution of Kidnapping and Abduction Cases by Age Groups')
plt.legend()
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 21
#      19 plt.bar(age_groups, male_cases, label='Male')
#      20 plt.bar(age_groups, female_cases, bottom=male_cases, label='Female')
# ---> 21 plt.bar(age_groups, total_cases, bottom=male_cases+female_cases, label='Total')
#      22 plt.xlabel('Age Groups')
#      23 plt.ylabel('Number of Cases')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2739, in bar(x, height, width, bottom, align, data, **kwargs)
#    2728 @_copy_docstring_and_deprecators(Axes.bar)
#    2729 def bar(
#    2730     x: float | ArrayLike,
#    (...)
#    2737     **kwargs,
#    2738 ) -> BarContainer:
# -> 2739     return gca().bar(
#    2740         x,
#    2741         height,
#    2742         width=width,
#    2743         bottom=bottom,
#    2744         align=align,
# ...

# %%
# Pie Chart

import matplotlib.pyplot as plt

gender_labels = ['Male', 'Female', 'Total']
# Calculate the sums of each gender category
male_cases_total = data.loc[:, ['Below 6 Years- M', '6 to 12 yrs- M', '12  to 16 yrs- M', '16  to 18 yrs- M', '18 to 30 yrs- M', '30 to 60 yrs- M', 'Above 60 yrs- M']].sum().sum()
female_cases_total = data.loc[:, ['Below 6 Years- F', '6 to 12 yrs- F', '12  to 16 yrs- F', '16  to 18 yrs- F', '18 to 30 yrs- F', '30 to 60 yrs- F', 'Above 60 yrs- F']].sum().sum()
total_cases = data.loc[:, ['Below 6 Years- T', '6 to 12 yrs- T', '12  to 16 yrs- T', '16  to 18 yrs- T', '18 to 30 yrs- T', '30 to 60 yrs- T', 'Above 60 yrs- T']].sum().sum()

gender_data = [male_cases_total, female_cases_total, total_cases]

plt.figure(figsize=(8, 6))
plt.pie(gender_data, labels=gender_labels, autopct='%1.1f%%')
plt.title('Distribution of Kidnapping and Abduction Cases by Gender')
plt.show()

# %%
#Stacked area chart for the trend of different case types over the years
    
plt.figure(figsize=(12, 6))
plt.stackplot(data['Year'], data['eo cases'], data['w cases'], data['cc cases'], data['violent cases'], data['sll cases'], data['ipc cases'], labels=['Economic Off cases', 'Crime ag Women', 'Cyber Crime cases', 'Violent Crimes', 'SSL', 'IPC'])
plt.xlabel('Year')
plt.ylabel('Number of cases')
plt.title('Trend of Different Case Types over the Years')
plt.legend()
plt.show()

# %%
#Grouped bar chart for the distribution of K&A cases by age groups and gender

age_groups = ['Below 6 Years', '6 to 12 yrs', '12  to 16 yrs', '16  to 18 yrs', '18 to 30 yrs', '30 to 60 yrs', 'Above 60 yrs']
male_cases = data[['Below 6 Years- M', '6 to 12 yrs- M', '12  to 16 yrs- M', '16  to 18 yrs- M', '18 to 30 yrs- M', '30 to 60 yrs- M', 'Above 60 yrs- M']].sum()
female_cases = data[['Below 6 Years- F', '6 to 12 yrs- F', '12  to 16 yrs- F', '16  to 18 yrs- F', '18 to 30 yrs- F', '30 to 60 yrs- F', 'Above 60 yrs- F']].sum()

x = range(len(age_groups))
width = 0.35

plt.figure(figsize=(12, 6))
plt.bar(x, male_cases, width, label='Male')
plt.bar(x, female_cases, width, bottom=male_cases, label='Female')
plt.xlabel('Age Groups')
plt.ylabel('Number of Cases')
plt.title('Distribution of Kidnapping and Abduction Cases by Age Groups and Gender')
plt.legend()
plt.xticks(x, age_groups, rotation=45)
plt.show()

# %%
#Example 7: Box plot for the distribution of K&A cases by age groups

age_groups = ['Below 6 Years', '6 to 12 yrs', '12 to 16 yrs', '16 to 18 yrs', '18 to 30 yrs', '30 to 60 yrs', 'Above 60 yrs']
data = [
    data['Below 6 Years- T'],
    data['6 to 12 yrs- T'],
    data['12  to 16 yrs- T'],
    data['16  to 18 yrs- T'],
    data['18 to 30 yrs- T'],
    data['30 to 60 yrs- T'],
    data['Above 60 yrs- T']
]

plt.figure(figsize=(12, 6))
plt.boxplot(data, labels=age_groups)
plt.xlabel('Age Groups')
plt.ylabel('Number of Cases')
plt.title('Distribution of Kidnapping and Abduction Cases by Age Groups (Boxplot)')
plt.show()

# %%
# Heatmap for the correlation matrix of different attributes
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame(data)

correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))
plt.imshow(correlation_matrix, cmap='coolwarm', vmin=-1, vmax=1)
plt.colorbar(label='Correlation')
plt.xticks(range(len(correlation_matrix.columns)), correlation_matrix.columns, rotation=45)
plt.yticks(range(len(correlation_matrix.columns)), correlation_matrix.columns)
plt.title('Correlation Matrix of Attributes')
plt.show()

# %%
#Area plot for the distribution of cases over the years

data = pd.DataFrame({
    'YEAR': [2018, 2019, 2020, 2021],
    'eo cases': [100, 200, 150, 300],
    'w cases': [150, 250, 100, 200],
    'cc cases': [50, 100, 50, 150]
})

plt.figure(figsize=(12, 6))
plt.stackplot(data['YEAR'], data['eo cases'], data['w cases'], data['cc cases'], labels=['eo cases', 'w cases', 'cc cases'])
plt.xlabel('Year')
plt.ylabel('Number of Cases')
plt.title('Distribution of Cases over the Years')
plt.legend(loc='upper left')
plt.show()

# %%
# pd.merge() function is used to combine data from multiple DataFrames based on a common key or keys.
# 'common_key' - 'Year' and 'City'

data = pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(data_eo, data_w, on=['City', 'Year'], how='inner'), data_cc, on=['City', 'Year'], how='inner'), data_v, on=['City', 'Year'], how='inner'), data_ka, on=['City', 'Year'], how='inner'), data_sll, on=['City', 'Year'], how='inner'), data_ipc, on=['City', 'Year'], how='inner')

# to_csv() function in pandas is used to save a DataFrame object as a CSV file

data.to_csv('dataset_data.csv', index=False)
print(data)
# Out:
#     Year        City  eo cases  w cases  cc cases  violent cases  \
# 0   2017   Ahmedabad       608     1681       108             90
# 1   2017   Bengaluru      3463     5624       292            235
# 2   2017     Chennai       663     1980        31            154
# 3   2017  Coimbatore       145      101        33             21
# 4   2017       Delhi      4808    32081       187            400
# ..   ...         ...       ...      ...       ...            ...
# 90  2021      Mumbai      5671    17180      1584             95
# 91  2021      Nagpur       541     1627       261             76
# 92  2021       Patna      1181     1071       517            100
# 93  2021        Pune       705     2709       411            121
# 94  2021       Surat       663      682       421           1955
#
#     Below 6 Years- M  Below 6 Years- F  Below 6 Years- T  6 to 12 yrs- M  ...  \
# 0                  4                 1                 5              11  ...
# ...

# %% [markdown]
# #### CHANGE x to derive distribution for other attributes

# %%
# Bar chart for the rate of eo cases per 100,000 population by city

import matplotlib.pyplot as plt
import pandas as pd

# Bar chart for the rate of Economic Off cases per 100,000
plt.figure(figsize=(12, 6))
eo_rate = (data['eo cases'] / data['eo cases'].sum()) * 100000
plt.bar(data['City'], eo_rate)
plt.xlabel('City')
plt.ylabel('Rate of Economic Off Cases per 100,000')
plt.title('Rate of Economic Off Cases per 100,000 by City')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar chart for the rate of Crime against Women cases per 100,000 population by city

import matplotlib.pyplot as plt
import pandas as pd


plt.figure(figsize=(12, 6))
eo_rate = (data['w cases'] / data['w cases'].sum()) * 100000
plt.bar(data['City'], eo_rate)
plt.xlabel('City')
plt.ylabel('Rate of Crime against Women Cases per 100,000')
plt.title('Rate of Crime against Women Cases per 100,000 by City')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar chart for the rate of Cyber Crime cases per 100,000 population by city

import matplotlib.pyplot as plt
import pandas as pd


plt.figure(figsize=(12, 6))
eo_rate = (data['cc cases'] / data['cc cases'].sum()) * 100000
plt.bar(data['City'], eo_rate)
plt.xlabel('City')
plt.ylabel('Rate of Cyber Crime Cases per 100,000')
plt.title('Rate of Cyber Crime Cases per 100,000 by City')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar chart for the rate of violent Crime cases per 100,000 population by city

import matplotlib.pyplot as plt
import pandas as pd


plt.figure(figsize=(12, 6))
eo_rate = (data['violent cases'] / data['violent cases'].sum()) * 100000
plt.bar(data['City'], eo_rate)
plt.xlabel('City')
plt.ylabel('Rate of violent Crime Cases per 100,000')
plt.title('Rate of violent Crime Cases per 100,000 by City')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar chart for the rate of SLL cases per 100,000 population by city

import matplotlib.pyplot as plt
import pandas as pd


plt.figure(figsize=(12, 6))
eo_rate = (data['sll cases'] / data['sll cases'].sum()) * 100000
plt.bar(data['City'], eo_rate)
plt.xlabel('City')
plt.ylabel('Rate of SLL Cases per 100,000')
plt.title('Rate of SLL Cases per 100,000 by City')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar chart for the rate of IPC cases per 100,000 population by city

import matplotlib.pyplot as plt
import pandas as pd


plt.figure(figsize=(12, 6))
eo_rate = (data['ipc cases'] / data['ipc cases'].sum()) * 100000
plt.bar(data['City'], eo_rate)
plt.xlabel('City')
plt.ylabel('Rate of IPC Cases per 100,000')
plt.title('Rate of IPC Cases per 100,000 by City')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar chart for the rate of eo cases per 100,000 population by Year

import matplotlib.pyplot as plt
import pandas as pd

# Bar chart for the rate of Economic Off cases per 100,000
plt.figure(figsize=(12, 6))
eo_rate = (data['eo cases'] / data['eo cases'].sum()) * 100000
plt.bar(data['Year'], eo_rate, color=c)
plt.xlabel('Year')
plt.ylabel('Rate of Economic Off Cases per 100,000')
plt.title('Rate of Economic Off Cases per 100,000 by Year')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar chart for the rate of Crime against Women cases per 100,000 population by Year

import matplotlib.pyplot as plt
import pandas as pd


plt.figure(figsize=(12, 6))
eo_rate = (data['w cases'] / data['w cases'].sum()) * 100000
plt.bar(data['Year'], eo_rate, color=c)
plt.xlabel('Year')
plt.ylabel('Rate of Crime against Women Cases per 100,000')
plt.title('Rate of Crime against Women Cases per 100,000 by Year')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar chart for the rate of Cyber Crime cases per 100,000 population by Year

import matplotlib.pyplot as plt
import pandas as pd


plt.figure(figsize=(12, 6))
eo_rate = (data['cc cases'] / data['cc cases'].sum()) * 100000
plt.bar(data['Year'], eo_rate, color=c)
plt.xlabel('Year')
plt.ylabel('Rate of Cyber Crime Cases per 100,000')
plt.title('Rate of Cyber Crime Cases per 100,000 by Year')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar chart for the rate of violent Crime cases per 100,000 population by Year

import matplotlib.pyplot as plt
import pandas as pd


plt.figure(figsize=(12, 6))
eo_rate = (data['violent cases'] / data['violent cases'].sum()) * 100000
plt.bar(data['Year'], eo_rate, color=c)
plt.xlabel('Year')
plt.ylabel('Rate of violent Crime Cases per 100,000')
plt.title('Rate of violent Crime Cases per 100,000 by Year')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar chart for the rate of SLL cases per 100,000 population by Year

import matplotlib.pyplot as plt
import pandas as pd


plt.figure(figsize=(12, 6))
eo_rate = (data['sll cases'] / data['sll cases'].sum()) * 100000
plt.bar(data['Year'], eo_rate, color=c)
plt.xlabel('Year')
plt.ylabel('Rate of SLL Cases per 100,000')
plt.title('Rate of SLL Cases per 100,000 by Year')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar chart for the rate of IPC cases per 100,000 population by Year

import matplotlib.pyplot as plt
import pandas as pd


plt.figure(figsize=(12, 6))
eo_rate = (data['ipc cases'] / data['ipc cases'].sum()) * 100000
plt.bar(data['Year'], eo_rate, color=c)
plt.xlabel('Year')
plt.ylabel('Rate of IPC Cases per 100,000')
plt.title('Rate of IPC Cases per 100,000 by Year')
plt.xticks(rotation=45)
plt.show()
